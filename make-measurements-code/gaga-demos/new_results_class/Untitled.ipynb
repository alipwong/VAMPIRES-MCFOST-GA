# %%
import bz2
import pickle
import numpy as np
import sys
sys.path.insert(0, '../../')
import VAMPIRES_data
import matplotlib.pyplot as plt

# %%
VAMP_path = "../../"
VAMP_data = "diffdata_RLeo_03_20170313_750-50_18holeNudged_0_0.idlvar"
VAMP_data_info = "cubeinfoMar2017.idlvar"

# load in external data
VAMP_data = VAMPIRES_data.VAMPIRES_data(VAMP_path + VAMP_data, VAMP_path + VAMP_data_info)
VAMP_data.vhvv -= np.mean(VAMP_data.vhvv) - 1
VAMP_data.vhvvu -= np.mean(VAMP_data.vhvvu) - 1

# %%
with bz2.open("./results_obj", "rb") as f:
    results = pickle.load(f)

results.results_folder = "./"

# %%
results.vis(VAMP_data)

# %%
results.vis(VAMP_data, Stokes = 'U')

# %%
results.correlate(VAMP_data)

# %%
results.correlate(VAMP_data, Stokes = 'Q')

# %%
results.animate("dust_mass", "radius", fmax = '15', inset = True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-5504c65b497c> in <module>
# ----> 1 results.animate("dust_mass", "radius", fmax = '15', inset = True)
#
# ~/anaconda3/lib/python3.7/site-packages/gaga/Results.py in animate(self, x_gene, y_gene, s, alpha, fps, bounds, log_scale, fmin, fmax, cmap, optimum, os, o_front, om, oc, inset, scale, filename)
#     281             ax1.scatter(optimum[0], optimum[1], s=os, marker=om, c=oc,)
#     282         if inset:
# --> 283             ax2.scatter(optimum[0], optimum[1], s=os, marker=om, c=oc, )
#     284
#     285         # Set up the colorbar range
#
# IndexError: list index out of range

# %%
results.animate("inner_radius", "outer_radius", fmax = '15', inset = True, optimum = [0,0])

# %%
gene_definition = {"dust_mass": (1e-7, 3e-7),
                   "inner_radius": (1, 10),
                   "radius": (1, 800),
                   "outer_radius": (2, 15)}
