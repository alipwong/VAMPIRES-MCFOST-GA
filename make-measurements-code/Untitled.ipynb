# %%
import bz2
import pickle
import numpy as np
import VAMPIRES_data
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
VAMP_path = ""
VAMP_data = "diffdata_RLeo_03_20170313_750-50_18holeNudged_0_0.idlvar"
VAMP_data_info = "cubeinfoMar2017.idlvar"

# load in external data
VAMP_data = VAMPIRES_data.VAMPIRES_data(VAMP_path + VAMP_data, VAMP_path + VAMP_data_info)

VAMP_data.vhvv -= np.mean(VAMP_data.vhvv) - 1
VAMP_data.vhvvu -= np.mean(VAMP_data.vhvvu) - 1

# %%
with bz2.open("./new_results_class/results_obj", "rb") as f:
    results = pickle.load(f)

results.results_folder = "./new_results_class/"

# %%
results.vis(VAMP_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-eab7cf47ddc7> in <module>
# ----> 1 results.vis(VAMP_data)
#
# ~/anaconda3/lib/python3.7/site-packages/gaga/Results.py in vis(self, VAMP_data, filename, Stokes, fps, ylim)
#     488         else:
#     489             ani.save("{}/visibilities_{}.gif".format(self.results_folder, Stokes),
# --> 490                      writer='imagemagick', fps=fps)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1167                 for anim in all_anim:
#    1168                     # Clear the initial frame
# -> 1169                     anim._init_draw()
#    1170                 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1171                     for anim, d in zip(all_anim, data):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _init_draw(self)
#    1738         # artists.
#    1739         if self._init_func is None:
# -> 1740             self._draw_frame(next(self.new_frame_seq()))
#    1741
#    1742         else:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1760         # Call the func with framedata and args. If blitting is desired,
#    1761         # func needs to return a sequence of any artists that were modified.
# -> 1762         self._drawn_artists = self._func(framedata, *self._args)
#    1763         if self._blit:
#    1764             if self._drawn_artists is None:
#
# ~/anaconda3/lib/python3.7/site-packages/gaga/Results.py in __draw_vis(self, i, ax, VAMP_data, Stokes, baseline_colours, bar_colour, ylim)
#     440
#     441         plt.cla()
# --> 442         ind = self.index_mins(self)
#     443         ax.set_ylim(ylim)
#     444
#
# TypeError: index_mins() takes 1 positional argument but 2 were given

# %%
results.correlate(VAMP_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-cce196080ffd> in <module>
# ----> 1 results.correlate(VAMP_data)
#
# ~/anaconda3/lib/python3.7/site-packages/gaga/Results.py in correlate(self, VAMP_data, filename, Stokes, fps)
#     435         else:
#     436             ani.save("{}/Correlation_{}.gif".format(self.results_folder, Stokes),
# --> 437                      writer='imagemagick', fps=fps)
#     438
#     439     def __draw_vis(self, i, ax, VAMP_data, Stokes, baseline_colours, bar_colour, ylim):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1167                 for anim in all_anim:
#    1168                     # Clear the initial frame
# -> 1169                     anim._init_draw()
#    1170                 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1171                     for anim, d in zip(all_anim, data):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _init_draw(self)
#    1738         # artists.
#    1739         if self._init_func is None:
# -> 1740             self._draw_frame(next(self.new_frame_seq()))
#    1741
#    1742         else:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1760         # Call the func with framedata and args. If blitting is desired,
#    1761         # func needs to return a sequence of any artists that were modified.
# -> 1762         self._drawn_artists = self._func(framedata, *self._args)
#    1763         if self._blit:
#    1764             if self._drawn_artists is None:
#
# ~/anaconda3/lib/python3.7/site-packages/gaga/Results.py in __draw_correlate(self, i, ax, VAMP_data, Stokes, baseline_colours, bar_colour)
#     381
#     382         plt.cla()
# --> 383         ind = self.index_mins(self)
#     384         ax.set_xlim([0.97, 1.04])
#     385         ax.set_ylim([0.97, 1.04])
#
# TypeError: index_mins() takes 1 positional argument but 2 were given
